# %%
import requests
import pandas as pd
from datetime import datetime

# %%
url = "https://covid19.ddc.moph.go.th/api/Cases/today-cases-line-lists"

# %%
r = requests.get(url)
data_covid = r.json()

# %%
df = pd.DataFrame(data_covid)

# %%
df
# Out:
#      year  weeknum gender age_number age_range   job  risk patient_type  \
# 0    2024        8   หญิง         51  50-59 ปี  None  None            -
# 1    2024        8   หญิง         47  40-49 ปี  None  None            -
# 2    2024        8   หญิง         19  10-19 ปี  None  None            -
# 3    2024        8   หญิง         45  40-49 ปี  None  None            -
# 4    2024        8    ชาย         74  >= 70 ปี  None  None            -
# ..    ...      ...    ...        ...       ...   ...   ...          ...
# 457  2024        8   หญิง         83  >= 70 ปี  None  None            -
# 458  2024        8    ชาย         85  >= 70 ปี  None  None            -
# 459  2024        8    ชาย         33  30-39 ปี  None  None            -
# 460  2024        8   หญิง         26  20-29 ปี  None  None            -
# 461  2024        8    ชาย         48  40-49 ปี  None  None            -
#
#           province reporting_group     region_odpc                     region  \
# 0    กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)  กรุงเทพมหานคร และ ปริมณฑล
# 1            ชุมพร         เคสปกติ          เขต 11                     ภาคใต้
# 2           สกลนคร         เคสปกติ           เขต 8      ภาคตะวันออกเฉียงเหนือ
# 3    กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)  กรุงเทพมหานคร และ ปริมณฑล
# 4           บึงกาฬ         เคสปกติ           เขต 8      ภาคตะวันออกเฉียงเหนือ
# ..             ...             ...             ...                        ...
# 457      เชียงใหม่         เคสปกติ           เขต 1                   ภาคเหนือ
# 458      อุทัยธานี         เคสปกติ           เขต 3                    ภาคกลาง
# 459       ปทุมธานี         เคสปกติ           เขต 4  กรุงเทพมหานคร และ ปริมณฑล
# 460         ชลบุรี         เคสปกติ           เขต 6                ภาคตะวันออก
# 461     ปราจีนบุรี         เคสปกติ           เขต 6                ภาคตะวันออก
#
#              update_date
# 0    2024-03-03 17:00:47
# 1    2024-03-03 17:00:47
# 2    2024-03-03 17:00:47
# 3    2024-03-03 17:00:47
# 4    2024-03-03 17:00:47
# ..                   ...
# 457  2024-03-03 17:00:47
# 458  2024-03-03 17:00:47
# 459  2024-03-03 17:00:47
# 460  2024-03-03 17:00:47
# 461  2024-03-03 17:00:47
#
# [462 rows x 13 columns]

# %%
columns = ["year","weeknum","gender","age_number","age_range","job","risk","patient_type","province","reporting_group","region_odpc","region","update_date"]
new_columns = ["Year","Weeknum","Gender","Age (Years)","Age_Range (Years)","Job","Risk","Patient_Type","Province","Reporting_Group","Region_Odpc","Region","Update_Date"]

# %%
for new_column,column in zip(new_columns,columns) :
    df[new_column] = df[column]

# %%
df
# Out:
#      year  weeknum gender age_number age_range   job  risk patient_type  \
# 0    2024        8   หญิง         51  50-59 ปี  None  None            -
# 1    2024        8   หญิง         47  40-49 ปี  None  None            -
# 2    2024        8   หญิง         19  10-19 ปี  None  None            -
# 3    2024        8   หญิง         45  40-49 ปี  None  None            -
# 4    2024        8    ชาย         74  >= 70 ปี  None  None            -
# ..    ...      ...    ...        ...       ...   ...   ...          ...
# 457  2024        8   หญิง         83  >= 70 ปี  None  None            -
# 458  2024        8    ชาย         85  >= 70 ปี  None  None            -
# 459  2024        8    ชาย         33  30-39 ปี  None  None            -
# 460  2024        8   หญิง         26  20-29 ปี  None  None            -
# 461  2024        8    ชาย         48  40-49 ปี  None  None            -
#
#           province reporting_group  ... Age (Years) Age_Range (Years)   Job  \
# 0    กรุงเทพมหานคร         เคสปกติ  ...          51          50-59 ปี  None
# 1            ชุมพร         เคสปกติ  ...          47          40-49 ปี  None
# 2           สกลนคร         เคสปกติ  ...          19          10-19 ปี  None
# 3    กรุงเทพมหานคร         เคสปกติ  ...          45          40-49 ปี  None
# 4           บึงกาฬ         เคสปกติ  ...          74          >= 70 ปี  None
# ..             ...             ...  ...         ...               ...   ...
# 457      เชียงใหม่         เคสปกติ  ...          83          >= 70 ปี  None
# 458      อุทัยธานี         เคสปกติ  ...          85          >= 70 ปี  None
# 459       ปทุมธานี         เคสปกติ  ...          33          30-39 ปี  None
# 460         ชลบุรี         เคสปกติ  ...          26          20-29 ปี  None
# 461     ปราจีนบุรี         เคสปกติ  ...          48          40-49 ปี  None
#
#      Risk  Patient_Type       Province Reporting_Group     Region_Odpc  \
# 0    None             -  กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)
# 1    None             -          ชุมพร         เคสปกติ          เขต 11
# 2    None             -         สกลนคร         เคสปกติ           เขต 8
# 3    None             -  กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)
# 4    None             -         บึงกาฬ         เคสปกติ           เขต 8
# ..    ...           ...            ...             ...             ...
# 457  None             -      เชียงใหม่         เคสปกติ           เขต 1
# 458  None             -      อุทัยธานี         เคสปกติ           เขต 3
# 459  None             -       ปทุมธานี         เคสปกติ           เขต 4
# 460  None             -         ชลบุรี         เคสปกติ           เขต 6
# 461  None             -     ปราจีนบุรี         เคสปกติ           เขต 6
#
#                         Region          Update_Date
# 0    กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 1                       ภาคใต้  2024-03-03 17:00:47
# 2        ภาคตะวันออกเฉียงเหนือ  2024-03-03 17:00:47
# 3    กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 4        ภาคตะวันออกเฉียงเหนือ  2024-03-03 17:00:47
# ..                         ...                  ...
# 457                   ภาคเหนือ  2024-03-03 17:00:47
# 458                    ภาคกลาง  2024-03-03 17:00:47
# 459  กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 460                ภาคตะวันออก  2024-03-03 17:00:47
# 461                ภาคตะวันออก  2024-03-03 17:00:47
#
# [462 rows x 26 columns]

# %%
for column in columns:
    df.drop(columns=[column], inplace=True ,axis=1)

# %%
df["Age_Range (Years)"] = df["Age_Range (Years)"].str.replace('ปี', '')

# %%
df
# Out:
#      Year  Weeknum Gender Age (Years) Age_Range (Years)   Job  Risk  \
# 0    2024        8   หญิง          51            50-59   None  None
# 1    2024        8   หญิง          47            40-49   None  None
# 2    2024        8   หญิง          19            10-19   None  None
# 3    2024        8   หญิง          45            40-49   None  None
# 4    2024        8    ชาย          74            >= 70   None  None
# ..    ...      ...    ...         ...               ...   ...   ...
# 457  2024        8   หญิง          83            >= 70   None  None
# 458  2024        8    ชาย          85            >= 70   None  None
# 459  2024        8    ชาย          33            30-39   None  None
# 460  2024        8   หญิง          26            20-29   None  None
# 461  2024        8    ชาย          48            40-49   None  None
#
#     Patient_Type       Province Reporting_Group     Region_Odpc  \
# 0              -  กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)
# 1              -          ชุมพร         เคสปกติ          เขต 11
# 2              -         สกลนคร         เคสปกติ           เขต 8
# 3              -  กรุงเทพมหานคร         เคสปกติ  เขต 13 (สปคม.)
# 4              -         บึงกาฬ         เคสปกติ           เขต 8
# ..           ...            ...             ...             ...
# 457            -      เชียงใหม่         เคสปกติ           เขต 1
# 458            -      อุทัยธานี         เคสปกติ           เขต 3
# 459            -       ปทุมธานี         เคสปกติ           เขต 4
# 460            -         ชลบุรี         เคสปกติ           เขต 6
# 461            -     ปราจีนบุรี         เคสปกติ           เขต 6
#
#                         Region          Update_Date
# 0    กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 1                       ภาคใต้  2024-03-03 17:00:47
# 2        ภาคตะวันออกเฉียงเหนือ  2024-03-03 17:00:47
# 3    กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 4        ภาคตะวันออกเฉียงเหนือ  2024-03-03 17:00:47
# ..                         ...                  ...
# 457                   ภาคเหนือ  2024-03-03 17:00:47
# 458                    ภาคกลาง  2024-03-03 17:00:47
# 459  กรุงเทพมหานคร และ ปริมณฑล  2024-03-03 17:00:47
# 460                ภาคตะวันออก  2024-03-03 17:00:47
# 461                ภาคตะวันออก  2024-03-03 17:00:47
#
# [462 rows x 13 columns]

# %%
print(df.dtypes)
# Out:
# Year                  int64
# Weeknum               int64
# Gender               object
# Age (Years)          object
# Age_Range (Years)    object
# Job                  object
# Risk                 object
# Patient_Type         object
# Province             object
# Reporting_Group      object
# Region_Odpc          object
# Region               object
# Update_Date          object
# dtype: object

# %%
df["Age (Years)"] = df["Age (Years)"].replace({'0.0': 0})  # Replace the value '0.0' with 0.

# %%
df["Age (Years)"] = df["Age (Years)"].astype(int)

# %%
df['Update_Date'] = pd.to_datetime(df['Update_Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 462 entries, 0 to 461
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Year               462 non-null    int64
#  1   Weeknum            462 non-null    int64
#  2   Gender             462 non-null    object
#  3   Age (Years)        462 non-null    int32
#  4   Age_Range (Years)  462 non-null    object
#  5   Job                0 non-null      object
#  6   Risk               0 non-null      object
#  7   Patient_Type       462 non-null    object
#  8   Province           462 non-null    object
#  9   Reporting_Group    462 non-null    object
#  10  Region_Odpc        462 non-null    object
#  11  Region             462 non-null    object
#  12  Update_Date        462 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int32(1), int64(2), object(9)
# memory usage: 45.2+ KB
